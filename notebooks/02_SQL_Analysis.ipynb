# %%
import pandas as pd
dataset_02 = pd.read_csv(r"C:\Data analysis project\OTT-Audience-Intelligence-Dashboard\datasets\cleaned_dataset.csv")
dataset_02.shape
# Out:
# (22998, 15)

# %%
dataset_02.columns
# Out:
# Index(['content_id', 'show_id', 'content_type', 'title', 'director', 'cast',
#        'country', 'date_added', 'release_year', 'rating', 'duration', 'genre',
#        'description', 'platform', 'primary_genre'],
#       dtype='object')

# %%
dataset_02.head()
# Out:
#    content_id show_id content_type                  title         director  \
# 0           1      s1        Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           2      s2      TV Show          Blood & Water          Unknown
# 2           3      s3      TV Show              Ganglands  Julien Leclercq
# 3           4      s4      TV Show  Jailbirds New Orleans          Unknown
# 4           5      s5      TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# ...

# %%
dataset_02.shape
# Out:
# (22998, 15)

# %%
dataset_02.to_csv("cleaned_dataset_new.csv",index=False,encoding="utf-8")
